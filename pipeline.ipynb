# %%
import pickle
import pandas as pd

import os, sys
import numpy as np
import networkx as nx
import seaborn as sns
import scipy.stats as ss
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from matplotlib.colors import TwoSlopeNorm
from os.path import expanduser

sys.path.insert(1, os.path.join(sys.path[0], '..'))
import data_misc as dm
import model_misc as mm
import plot_misc as pm

# %%
# eventname, dataname = 'CNS_calls.evt', 'Copenhagen_nets'
# eventname, dataname = 'CNS_sms.evt', 'Copenhagen_nets'
# eventname, dataname = 'CollegeMsg.evt', 'SNAP'
# eventname, dataname = 'email_Eu_core.evt', 'SNAP'
# eventname, dataname = 'email.evt', 'greedy_walk_nets'
# eventname, dataname = 'forum.evt', 'greedy_walk_nets'
# eventname, dataname = 'messages.evt', 'greedy_walk_nets'
# eventname, dataname = 'pok.evt', 'greedy_walk_nets'
# eventname, dataname = 'Enron.evt', 'Enron'
# eventname, dataname = 'fb.evt', 'greedy_walk_nets'
# eventname, dataname = 'MPC_Wu_SD01.evt', 'SMS_net'
# eventname, dataname = 'MPC_Wu_SD02.evt', 'SMS_net'
# eventname, dataname = 'MPC_Wu_SD03.evt', 'SMS_net'

# eventname, dataname = 'contact.evt', 'offline_nets'
# eventname, dataname = 'sp_hospital.evt', 'offline_nets'
# eventname, dataname = 'sp_colocation_LH10.evt', 'offline_nets'
# eventname, dataname = 'sp_colocation_InVS13.evt', 'offline_nets'
eventname, dataname = 'sp_colocation_Thiers13.evt', 'offline_nets'
# eventname, dataname = 'sp_high_school_new_2011.evt', 'offline_nets'
# eventname, dataname = 'sp_office.evt', 'offline_nets'
# eventname, dataname = 'sp_high_school_new_2012.evt', 'offline_nets'
# eventname, dataname = 'sp_hypertext_contacts.evt', 'offline_nets'

root_data = '../temporal_networks/'

saveloc = './files/data/'

# %%
savename = f'{root_data}/{dataname}/data_formatted/{eventname}'
events = pd.read_csv(savename, sep=';', header=None)
savename
# Out:
# '../temporal_networks//offline_nets/data_formatted/sp_colocation_Thiers13.evt'

# %%
events
# Out:
#            0    1       2
# 0          1  313  202760
# 1          1  313  202760
# 2          1  313  202760
# 3          1  313  202760
# 4          1  313  202760
# ...      ...  ...     ...
# 3688546  311  326  229480
# 3688547  311  326  229760
# 3688548  311  326  230200
# 3688549  311  326  230920
# 3688550  311  326  231160
#
# [3688551 rows x 3 columns]

# %%
# datasets = [
#                 ('Copenhagen_nets', 'CNS_calls.evt'),
#                 ('Copenhagen_nets', 'CNS_sms.evt'),
#                 ('Enron', 'Enron.evt'),
#                 ('greedy_walk_nets', 'email.evt'),
#                 ('greedy_walk_nets', 'eml2.evt'),
#                 ('greedy_walk_nets', 'fb.evt'),
#                 ('greedy_walk_nets', 'forum.evt'),
#                 ('greedy_walk_nets', 'messages.evt'),
#                 ('greedy_walk_nets', 'pok.evt'),
#                 ('SMS_net', 'MPC_Wu_SD01.evt'),
#                 ('SMS_net', 'MPC_Wu_SD02.evt'),
#                 ('SMS_net', 'MPC_Wu_SD03.evt'),
#                 ('SNAP', 'email_Eu_core.evt'),
#                 ('SNAP', 'CollegeMsg.evt'),
#                 ('offline_nets', 'sp_hospital.evt'),
#                 ('offline_nets', 'sp_colocation_LH10.evt'),
#                 ('offline_nets', 'sp_office.evt'),
#                 ('offline_nets', 'sp_colocation_InVS13.evt'),
#                 ('offline_nets', 'sp_colocation_InVS15.evt'),
#                 ('offline_nets', 'sp_primary_school.evt'),
#                 ('offline_nets', 'sp_colocation_LyonSchool.evt'),
#                 ('offline_nets', 'sp_high_school_new_2011.evt'),
#                 ('offline_nets', 'sp_high_school_new_2012.evt'),
#                 ('offline_nets', 'sp_colocation_Thiers13.evt'),
#                 ('offline_nets', 'sp_high_school_proximity.evt'),
#                 ('offline_nets', 'reality_mining.evt'),
#                 ('offline_nets', 'contact.evt'),
#                 ('offline_nets', 'sp_colocation_SFHH.evt'),
#                 ('offline_nets', 'sp_hypertext_contacts.evt'),
#                 ('offline_nets', 'sp_infectious.evt')
#             ]

# %%
# datasets = [
#                 ('Copenhagen_nets', 'CNS_calls.evt'),
#                 ('Copenhagen_nets', 'CNS_sms.evt'),
#                 ('Enron', 'Enron.evt'),
#                 ('greedy_walk_nets', 'email.evt'),
#                 ('greedy_walk_nets', 'eml2.evt'),
#                 ('greedy_walk_nets', 'fb.evt'),
#                 ('greedy_walk_nets', 'forum.evt'),
#                 ('greedy_walk_nets', 'messages.evt'),
#                 ('greedy_walk_nets', 'pok.evt'),
#                 ('SMS_net', 'MPC_Wu_SD01.evt'),
#                 ('SMS_net', 'MPC_Wu_SD02.evt'),
#                 ('SMS_net', 'MPC_Wu_SD03.evt'),
#                 ('SNAP', 'email_Eu_core.evt'),
#                 ('SNAP', 'CollegeMsg.evt')
#             ]

# dm.data_params( datasets, root_data, 'n', saveloc )

# %%
dm.egonet_props_acts_pieces( dataname, eventname, root_data, 'n', saveloc )
# Out:
# ./files/data/egonet_props_pieces_sp_colocation_Thiers13.pkl
# ./files/data/egonet_acts_pieces_sp_colocation_Thiers13.pkl
# /Users/pkt949/Downloads/offline_egonets_C72h-main/Farsignatures-master/data_misc.py:125: FutureWarning: The provided callable <built-in function min> is currently using np.minimum.reduce. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string np.minimum.reduce instead.
#   amins = egonet_acts.groupby('nodei').apply( min )
# /Users/pkt949/Downloads/offline_egonets_C72h-main/Farsignatures-master/data_misc.py:126: FutureWarning: The provided callable <built-in function max> is currently using np.maximum.reduce. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string np.maximum.reduce instead.
#   amaxs = egonet_acts.groupby('nodei').apply( max )
# ...

# %%
dm.egonet_fits_piece( dataname, eventname, 0, root_data, 'n', saveloc, alpha_bounds=(1e-4, 1e3), nsims=2500 )
# Out:
# ./files/data/egonet_props_pieces_sp_colocation_Thiers13.pkl
# ./files/data/egonet_acts_pieces_sp_colocation_Thiers13.pkl
# ego 0 out of 327
# ego 10 out of 327
# ego 20 out of 327
# ego 30 out of 327
# ego 40 out of 327
# ego 50 out of 327
# ego 60 out of 327
# ego 70 out of 327
# ego 80 out of 327
# ego 90 out of 327
# ego 100 out of 327
# ego 110 out of 327
# ego 120 out of 327
# ego 130 out of 327
# ego 140 out of 327
# ego 150 out of 327
# ego 160 out of 327
# ego 170 out of 327
# ego 180 out of 327
# ego 190 out of 327
# ego 200 out of 327
# ego 210 out of 327
# ego 220 out of 327
# ego 230 out of 327
# ego 240 out of 327
# ego 250 out of 327
# ego 260 out of 327
# ego 270 out of 327
# ego 280 out of 327
# ego 290 out of 327
# ego 300 out of 327
# ego 310 out of 327
# ego 320 out of 327
# measure      alpha   KS_stat  KS_pval   W2_stat  W2_pval   U2_stat  U2_pval  \
# nodei
# 0       -10.851635  0.125374   0.7016  0.085300   0.6364  0.053668   0.5648
# ...

# %%
dm.egonet_fits_piece( dataname, eventname, 1, root_data, 'n', saveloc, alpha_bounds=(1e-4, 1e3), nsims=2500 )
# Out:
# ./files/data/egonet_props_pieces_sp_colocation_Thiers13.pkl
# ./files/data/egonet_acts_pieces_sp_colocation_Thiers13.pkl
# ego 0 out of 327
# ego 10 out of 327
# ego 20 out of 327
# ego 30 out of 327
# ego 40 out of 327
# ego 50 out of 327
# ego 60 out of 327
# ego 70 out of 327
# ego 80 out of 327
# ego 90 out of 327
# ego 100 out of 327

# %%
dm.egonet_props_acts( dataname, eventname, root_data, 'n', saveloc )
# Out:
# /Users/pkt949/Downloads/offline_egonets_C72h-main/Farsignatures-master/data_misc.py:60: FutureWarning: The provided callable <built-in function min> is currently using np.minimum.reduce. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string np.minimum.reduce instead.
#   amins = egonet_acts_grouped.apply( min )
# /Users/pkt949/Downloads/offline_egonets_C72h-main/Farsignatures-master/data_misc.py:61: FutureWarning: The provided callable <built-in function max> is currently using np.maximum.reduce. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string np.maximum.reduce instead.
#   amaxs = egonet_acts_grouped.apply( max )
# (       degree  strength     act_avg       act_var  act_min  act_max
#  nodei
#  0           8       611   76.375000  17364.553571       10      400
#  1           4        77   19.250000     74.250000       10       28
# ...

# %%
loadflag = 'n' # to create them, loadflag = 'n', otherwise 'y'

# %%
dm.egonet_kernel( dataname, eventname, root_data, loadflag, saveloc )
# Out:
# ego 0 out of 169
# ego 100 out of 169
# <class 'pandas.core.indexes.base.Index'>
# (0, 0)        0.011142
# (0, 1)        0.133333
# (0, 2)        0.063492
# (0, 3)        0.333333
# (0, 4)        0.888889
#                 ...
# (168, 736)    1.000000
# (168, 737)    1.000000
# (168, 738)    1.000000
# (168, 739)    1.000000
# (168, 740)    0.000000
# Length: 27935, dtype: float64

# %%
dm.egonet_jaccard( eventname, loadflag, saveloc, nodei='nodei', nodej='nodej', saveflag=True )
# Out:
# nodei
# 0      1.000000
# 1      0.750000
# 2      1.000000
# 3      0.400000
# 4      0.666667
#          ...
# 164    0.909091
# 165    0.900000
# 166    0.666667
# 167    0.923077
# 168    0.666667
# Length: 169, dtype: float64

# %%
dm.egonet_fits( dataname, eventname, root_data, loadflag, saveloc, egonet_tuple=None, alpha_bounds=(1e-4, 1e3), nsims=2500)
# Out:
# ego 0 out of 169
# ego 10 out of 169
# ego 20 out of 169
# ego 30 out of 169
# ego 40 out of 169
# ego 50 out of 169
# ego 60 out of 169
# ego 70 out of 169
# ego 80 out of 169
# ego 90 out of 169
# ego 100 out of 169
# ego 110 out of 169
# ego 120 out of 169
# ego 130 out of 169
# ego 140 out of 169
# ego 150 out of 169
# ego 160 out of 169
# measure      alpha   KS_stat  KS_pval   W2_stat  W2_pval   U2_stat  U2_pval  \
# nodei
# 0        -9.590201  0.256093   0.3784  0.086931   0.4592  0.085518   0.2288
# 1        -9.260580  0.424769   0.1416  0.153721   0.1900  0.081507   0.2492
# 2       -18.728540  0.486682   0.0000  0.087876   0.2720  0.053704   0.5288
# 3       -10.535089  0.378243   0.3044  0.137036   0.3584  0.096366   0.2444
# 4       -14.432697  0.316641   0.3268  0.061497   0.3996  0.038397   0.3996
# ...            ...       ...      ...       ...      ...       ...      ...
# 164      -9.258634  0.165168   0.8188  0.047087   0.8732  0.024358   0.9672
# ...
